# %% [markdown]
# # Capstone Part 3: Solar data only
# ## By Elizabeth Tyree
#
#
# ### Problem Statement:
# ### Can the occurrence of sunspots be used to predict the frequency of earthquakes?
#
# ## Overall Capstone Outline (I am aware some datasets maybe missing data)
#
# Part 1 | Problem Statement: Can the occurrence of sunspots be used to predict the frequency of earthquakes?
#
# Part 2: Get Data (Data Wrangling)
# -> Data Sources
# -> What kind of data ( was it a csv, a paper file, an image, etc?)
# -> Example: I got my data from the Cenciuos, my first data set was a million rows, that included these key features..)
#
# Part 3: Data Preparation (Data cleaning\Munging)
# -> Explain what you did to your data and why.
# -> Plots show people all about your data!
#
# Part 4: 	Model building
# -> Standardize your data
# -> Cross Validation OR Train Test Split
# -> I chose this model because…..etc. (explain why you choose your model)
# -> What are you trying to predict and why?
#
# Part 5: Modeling (In no particular order)
# -> RNN
# -> ARIMA
# -> SARIMA (ARIMA for seasonal data)
#
# Part 6: Evaluation/Evaluation of Modeling
# -> Scores (amount of error or the amount of variance)
# -> Fourier Transform, look at both the data and the predictions in the frequency domain.
# -> What are the most important features?
# -> Feature importances
# -> And plot the most important features!!!!!
# -> Errors and Error Directionality
# -> Conclusions
# -> Recommendations
# -> Next steps if you had more time etc. Then come back to your conclusions slide and end with that slide! OR Create two slides, 1 for conclusions of the models and the 2nd for you presentation conclusions.)
#
#
# ## In Depth Outline
#
# Part 1: Data Summary | Datasets in possession
#
# -> The Centennial catalog from the USGS, contains earthquakes from 1900 to 2007.
#
#     Data Format: *.csv
#     Features: icat, msc1, mdo1, yr, mon, Day, hr, Min, sec, glat, glon, dep, greg, ntel, mag1, Fract_Year
#     Date Range: 01/01/1903 to 09/30/2007
#
# -> Reviewed Earthquakes data from the USGS 1900-2016 all magnitudes.
#
#     Data Format: *.csv
#     Features: time, latitude, longitude, depth, mag, magType, nst, gap, dmin, rms, net, id, updated, place, type,
#     horizontalError, depthError, magError, magNst, status, locationSource, magSource
#     Date Range: 1900-2016
#
# -> International Seismological Centre (ISC) catalog of earthquakes from 1900 to 2016.
#
#     Data Format: *.csv
#     Features:
#     Date Range: 1900-2016
#
# -> Preliminary Determination of Epicenters or PDE.
# “We use the word "Preliminary" for our final bulletin because the Bulletin of the International Seismological Centre is considered to be the final global archive of parametric earthquake data, in other words phase arrival (“pick”) times and amplitudes.”
#
#     Data Format: *.csv
#     Features: Date, ZTime, net, Year, Month, FracYear, Secs_from1973, latitude, longitude, mag
#     Date Range: 1900-2016
#
# -> Geomagnetic Data
#
#     Data Format: *.csv  and *.txt for hourly data, *.out for minute data.
#     Date Range: 01/01/1958 to 2007/12/31 for hourly data, 01/01/1985 to 12/31/2007 14:40pm.
#     Features:
#     -> Four hourly data: Year, Mon, Day, Hr, min, sec, DOYfromstart, FractionalDOY, Fractionalyear, Dst, HER, KAK, HON, SJG, sigma
#     -> For minute data:

# %%
import numpy as np
import pandas as pd
import patsy

from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression, RidgeCV, LassoCV, ElasticNetCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.ensemble import RandomForestRegressor

from pprint import pprint

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import ast
import datetime as dt
from datetime import timedelta
from datetime import datetime as dt2
import time
#from datetime import now

#jupyter notebook --NotebookApp.iopub_data_rate_limit=1.0e10 # Use this at the command line to expand rate limit!
# or the function prep_posts may not work properly.
plt.style.use('fivethirtyeight')

pd.set_option('display.max_columns', None) 
# %matplotlib inline

# %%
# Loading the ISSN_D_tot data, these are the daily sunspot numbers.
my_cols_d = ['Year','Month','Day','Frac_Year','Daily_Sun_Spot_Number', 'Flag'] # The file does not contain headers.

ISSN_D_tot = pd.read_csv('./data/ISSN_D_tot.csv',names=my_cols_d, engine='python')

# %%
ISSN_D_tot = pd.DataFrame(ISSN_D_tot)

# %%
ISSN_D_tot.head()
# Out:
#    Year  Month  Day  Frac_Year  Daily_Sun_Spot_Number  Flag
# 0  1818      1    1   1818.004                     -1     1
# 1  1818      1    2   1818.007                     -1     1
# 2  1818      1    3   1818.010                     -1     1
# 3  1818      1    4   1818.012                     -1     1
# 4  1818      1    5   1818.015                     -1     1

# %%
ISSN_D_tot.tail()
# Out:
#        Year  Month  Day  Frac_Year  Daily_Sun_Spot_Number  Flag
# 72007  2015      2   24   2015.149                     28     0
# 72008  2015      2   25   2015.151                     13     0
# 72009  2015      2   26   2015.154                     16     0
# 72010  2015      2   27   2015.157                     38     0
# 72011  2015      2   28   2015.159                     41     0

# %%
ISSN_D_tot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72012 entries, 0 to 72011
# Data columns (total 6 columns):
# Year                     72012 non-null int64
# Month                    72012 non-null int64
# Day                      72012 non-null int64
# Frac_Year                72012 non-null float64
# Daily_Sun_Spot_Number    72012 non-null int64
# Flag                     72012 non-null int64
# dtypes: float64(1), int64(5)
# memory usage: 3.3 MB

# %%
# Histogram of Daily Sunspot Numbers from the ISSN.
#bin_size = 0.5
#n_bins = 10/bin_size


plt.hist(ISSN_D_tot['Daily_Sun_Spot_Number'])    
# Add title and axis names
plt.title('Histogram of Daily Sunspot Numbers from the ISSN')
plt.xlabel('Sunspot Numbers') #Default is 10 bins
plt.ylabel('Count')
#plt.xlim(0,10)

# Show graphic
plt.show()

# %%
sns.set(rc={'figure.figsize':(12,9)})
f,ax = plt.subplots()
sns.distplot(ISSN_D_tot['Daily_Sun_Spot_Number'], bins=50, axlabel ='Sunspot Numbers')
ax.set_title('Histogram of Daily Sunspot Numbers from the ISSN')
ax.set_xlabel('Sunspot Numbers');
ax.set_ylabel('Count');

# %%
pd.crosstab(index=ISSN_D_tot['Daily_Sun_Spot_Number'],  # Make a crosstab
                      columns="count")      # Name the count column
# Out:
# col_0                  count
# Daily_Sun_Spot_Number
# -1                      3247
#  0                     10551
#  1                        25
#  2                        64
#  3                       140
#  4                        82
#  5                        63
#  6                        79
#  7                      1212
#  8                      1156
#  9                       698
#  10                      809
#  11                      784
#  12                      600
#  13                      680
#  14                     1106
#  15                      886
#  16                     1164
#  17                      839
#  18                      665
#  19                      745
#  20                      676
#  21                      552
#  22                      715
#  23                      631
#  24                      532
#  25                      586
#  26                      568
#  27                      544
#  28                      538
# ...                      ...
#  287                       1
#  288                       2
#  290                       5
#  291                       2
#  292                       3
#  293                       1
#  294                       1
#  295                       3
#  296                       1
#  297                       1
#  299                       2
#  300                       2
#  301                       1
#  302                       4
#  303                       1
#  305                       1
#  307                       1
#  308                       1
#  311                       2
#  312                       2
#  316                       1
#  317                       3
#  321                       1
#  323                       1
#  334                       2
#  337                       1
#  338                       1
#  342                       1
#  343                       1
#  355                       2
#
# [314 rows x 1 columns]

# %%
# Scatter plot of Daily Sunspot Numbers vs. Time
 
# Without regression fit:
f,ax = plt.subplots()
sns.regplot(x=ISSN_D_tot['Frac_Year'], y=ISSN_D_tot['Daily_Sun_Spot_Number'], fit_reg=False, ax = ax)
ax.set_title('Scatter plot of Daily Sunspot Number vs Time from 1/1/1815 to 2/28/2015')
ax.set_xlabel('Time (Years)');
ax.set_ylabel('Daily Sunspot Number');

# %%
# use the plot function
plt.plot(ISSN_D_tot['Frac_Year'],ISSN_D_tot['Daily_Sun_Spot_Number'])
# Add title and axis names
plt.title('Line Plot of Daily Sunspot Numbers vs Time from 1/1/1815 to 2/28/2015')
plt.xlabel('Time (Years)') #Default is 10 bins
plt.ylabel('Daiy Sunspot Numbers')
#plt.xlim(0,10)

# Show graphic
plt.show()

# %%
# Loading the ISSN_M_tot data, these are the Monthly sunspot numbers.
my_cols_m = ['Year','Month','Frac_Year','Monthly_Sun_Spot_Number','Flag1' ,'Smoothed_Monthly','Flag2'] # The file does not contain headers.

ISSN_M_tot = pd.read_csv('./data/ISSN_M_tot.csv',names=my_cols_m, engine='python')

# %%
ISSN_M_tot.head()
# Out:
#    Year  Month  Frac_Year  Monthly_Sun_Spot_Number  Flag1  Smoothed_Monthly  \
# 0  1749      1   1749.049                     58.0      1              -1.0
# 1  1749      2   1749.129                     62.6      1              -1.0
# 2  1749      3   1749.210                     70.0      1              -1.0
# 3  1749      4   1749.294                     55.7      1              -1.0
# 4  1749      5   1749.377                     85.0      1              -1.0
#
#    Flag2
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
ISSN_M_tot.tail()
# Out:
#       Year  Month  Frac_Year  Monthly_Sun_Spot_Number  Flag1  \
# 3189  2014     10   2014.790                     60.6      0
# 3190  2014     11   2014.873                     70.1      0
# 3191  2014     12   2014.957                     78.0      0
# 3192  2015      1   2015.042                     67.0      0
# 3193  2015      2   2015.123                     44.8      0
#
#       Smoothed_Monthly  Flag2
# 3189              -1.0      0
# 3190              -1.0      0
# 3191              -1.0      0
# 3192              -1.0      0
# 3193              -1.0      0

# %%
ISSN_M_tot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3194 entries, 0 to 3193
# Data columns (total 7 columns):
# Year                       3194 non-null int64
# Month                      3194 non-null int64
# Frac_Year                  3194 non-null float64
# Monthly_Sun_Spot_Number    3194 non-null float64
# Flag1                      3194 non-null int64
# Smoothed_Monthly           3194 non-null float64
# Flag2                      3194 non-null int64
# dtypes: float64(3), int64(4)
# memory usage: 174.8 KB

# %%
# Histogram of Daily Sunspot Numbers from the ISSN.
#bin_size = 0.5
#n_bins = 10/bin_size


plt.hist(ISSN_M_tot['Monthly_Sun_Spot_Number'])    
# Add title and axis names
plt.title('Histogram of Monthly Sunspot Numbers from Jan. 1749 to Feb. 2015')
plt.xlabel('Sunspot Numbers') #Default is 10 bins
plt.ylabel('Count')
#plt.xlim(0,10)

# Show graphic
plt.show()

# %%
sns.set(rc={'figure.figsize':(12,9)})
f,ax = plt.subplots()
sns.distplot(ISSN_M_tot['Monthly_Sun_Spot_Number'], bins=50, axlabel ='Sunspot Numbers')
ax.set_title('Histogram of Monthly Sunspot Numbers from Jan. 1749 to Feb. 2015')
ax.set_xlabel('Sunspot Numbers');
ax.set_ylabel('Count');

# %%
pd.crosstab(index=ISSN_M_tot['Monthly_Sun_Spot_Number'],  # Make a crosstab
                      columns="count")      # Name the count column
# Out:
# col_0                    count
# Monthly_Sun_Spot_Number
# 0.0                         67
# 0.1                          2
# 0.2                          8
# 0.3                          7
# 0.4                          4
# 0.5                         10
# 0.6                          5
# 0.7                          5
# 0.8                          7
# 0.9                          6
# 1.0                          6
# 1.1                          7
# 1.2                          1
# 1.3                          3
# 1.4                          4
# 1.5                          7
# 1.6                          5
# 1.7                          4
# 1.8                          3
# 1.9                          3
# 2.0                          2
# 2.1                          5
# 2.2                          3
# 2.3                          4
# 2.4                          8
# 2.5                          5
# 2.6                          3
# 2.7                          1
# 2.8                          7
# 2.9                          8
# ...                        ...
# 181.5                        1
# 182.3                        1
# 183.3                        1
# 185.7                        1
# 186.2                        1
# 187.2                        1
# 187.6                        1
# 188.0                        1
# 188.4                        1
# 188.8                        1
# 189.7                        1
# 190.7                        1
# 191.4                        1
# 192.1                        1
# 196.0                        1
# 196.2                        1
# 199.6                        1
# 200.2                        1
# 200.3                        1
# 200.7                        1
# 201.2                        1
# 201.3                        2
# 202.5                        1
# 206.2                        1
# 210.9                        1
# 217.4                        1
# 235.8                        1
# 238.9                        1
# 239.4                        1
# 253.8                        1
#
# [1224 rows x 1 columns]

# %%
# use the plot function
plt.plot(ISSN_M_tot['Frac_Year'],ISSN_M_tot['Monthly_Sun_Spot_Number'],label='Monthly Sunspot Numbers')
plt.plot(ISSN_M_tot['Frac_Year'],ISSN_M_tot['Smoothed_Monthly'],'r-',label='Smoothed Monthly Sunspots')

# Add title and axis names
plt.title('Line Plot of Monthly Sunspot Numbers vs Time from Jan. 1749 to Feb. 2015')
plt.xlabel('Time (Years)') #Default is 10 bins
plt.ylabel('Monthly Sunspot Numbers')
#plt.xlim(0,10)
plt.legend()
# Show graphic
plt.show()

# %%
# Loading the ISSN_M_tot data, these are the Monthly sunspot numbers.
my_cols_y = ['Frac_Year','Yearly_Sun_Spot_Number','Flag'] # The file does not contain headers.

ISSN_Y_tot = pd.read_csv('./data/ISSN_Y_tot.csv',names=my_cols_y, engine='python')

# %%
ISSN_Y_tot.head()
# Out:
#    Frac_Year  Yearly_Sun_Spot_Number  Flag
# 0     1700.5                     5.0     1
# 1     1701.5                    11.0     1
# 2     1702.5                    16.0     1
# 3     1703.5                    23.0     1
# 4     1704.5                    36.0     1

# %%
ISSN_Y_tot.tail()
# Out:
#      Frac_Year  Yearly_Sun_Spot_Number  Flag
# 310     2010.5                    16.5     1
# 311     2011.5                    55.7     1
# 312     2012.5                    57.7     1
# 313     2013.5                    64.9     1
# 314     2014.5                    79.0     0

# %%
# Histogram of Daily Sunspot Numbers from the ISSN.
#bin_size = 0.5
#n_bins = 10/bin_size


plt.hist(ISSN_Y_tot['Yearly_Sun_Spot_Number'])    
# Add title and axis names
plt.title('Histogram of Yearly Sunspot Numbers from 1700 to 2014')
plt.xlabel('Sunspot Numbers') #Default is 10 bins
plt.ylabel('Count')
#plt.xlim(0,10)

# Show graphic
plt.show()

# %%
sns.set(rc={'figure.figsize':(12,9)})
f,ax = plt.subplots()
sns.distplot(ISSN_Y_tot['Yearly_Sun_Spot_Number'], bins=50, axlabel ='Sunspot Numbers')
ax.set_title('Histogram of Yearly Sunspot Numbers from 1700 to 2014')
ax.set_xlabel('Sunspot Numbers');
ax.set_ylabel('Count');

# %%
pd.crosstab(index=ISSN_Y_tot['Yearly_Sun_Spot_Number'],  # Make a crosstab
                      columns="count")      # Name the count column
# Out:
# col_0                   count
# Yearly_Sun_Spot_Number
# 0.0                         3
# 1.4                         2
# 1.8                         1
# 2.0                         1
# 2.5                         1
# 2.7                         1
# 2.9                         1
# 3.0                         1
# 3.1                         1
# 3.4                         1
# 3.6                         1
# 4.0                         1
# 4.1                         1
# 4.3                         1
# 4.4                         1
# 5.0                         4
# 5.1                         1
# 5.5                         1
# 5.7                         1
# 5.8                         1
# 6.0                         1
# 6.2                         1
# 6.4                         1
# 6.6                         1
# 6.7                         2
# 6.8                         1
# 7.0                         1
# 7.1                         1
# 7.3                         1
# 7.5                         1
# ...                       ...
# 109.6                       1
# 111.0                       2
# 111.1                       1
# 112.3                       1
# 114.4                       1
# 115.9                       1
# 118.1                       1
# 119.6                       1
# 121.5                       1
# 122.0                       1
# 124.7                       1
# 125.9                       1
# 130.9                       1
# 132.0                       1
# 134.7                       1
# 136.3                       1
# 138.3                       1
# 139.1                       1
# 140.5                       1
# 141.7                       1
# 142.6                       1
# 145.7                       1
# 151.6                       1
# 154.4                       1
# 154.6                       1
# 155.4                       1
# 157.6                       1
# 159.0                       1
# 184.8                       1
# 190.2                       1
#
# [263 rows x 1 columns]

# %%
# use the plot function
plt.plot(ISSN_Y_tot['Frac_Year'],ISSN_Y_tot['Yearly_Sun_Spot_Number'],'k-')

# Add title and axis names
plt.title('Line Plot of Monthly Sunspot Numbers vs Time from Jan. 1749 to Feb. 2015')
plt.xlabel('Time (Years)') #Default is 10 bins
plt.ylabel('Yearly Sunspot Numbers')
#plt.xlim(0,10)

# Show graphic
plt.show()

# %%
# use the plot function
plt.plot(ISSN_D_tot['Frac_Year'],ISSN_D_tot['Daily_Sun_Spot_Number'],'y-',label='Daily Sunspots')
plt.plot(ISSN_M_tot['Frac_Year'],ISSN_M_tot['Monthly_Sun_Spot_Number'],'b-',label='Monthly Sunspots')
plt.plot(ISSN_M_tot['Frac_Year'],ISSN_M_tot['Smoothed_Monthly'],'r-',label='Smoothed Monthly Sunspots')
plt.plot(ISSN_Y_tot['Frac_Year'],ISSN_Y_tot['Yearly_Sun_Spot_Number'],'k-',label='Yearly Sunspots')

# Add title and axis names
plt.title('Line Plot Daily, Monthly, and Yearly Sunspot Numbers vs Time')
plt.xlabel('Time (Years)') #Default is 10 bins
plt.ylabel('Yearly Sunspot Numbers')
#plt.xlim(0,10)

plt.legend()
# Show graphic
plt.show()

# %%
# Loading the The Preliminary Determination of Epicenters (PDE) USGS data
pde = pd.read_csv('./data/EQ_pde.csv')

# %%
pde = pd.DataFrame(pde)

# %%
pde.shape
# Out:
# (586409, 10)

# %%
pde.head()
# Out:
#          Date     ZTime  net  Year  Month     FracYear  Secs_from1973  \
# 0  01-01-1973  03:46:09  pde  1973      1  1973.076923          13569
# 1  01-01-1973  05:22:29  pde  1973      1  1973.076923          19349
# 2  01-01-1973  09:28:57  pde  1973      1  1973.076923          34137
# 3  01-01-1973  21:35:58  pde  1973      1  1973.076923          77758
# 4  01-01-1973  21:41:17  pde  1973      1  1973.076923          78077
#
#    latitude  longitude  mag
# 0    -9.214    150.634  5.3
# 1   -15.012   -173.958  5.0
# 2   -22.161    -65.792  4.8
# 3    13.897    -44.876  4.4
# 4    13.743    -45.266  4.4

# %%
pde.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586409 entries, 0 to 586408
# Data columns (total 10 columns):
# Date             586409 non-null object
# ZTime            586409 non-null object
# net              586409 non-null object
# Year             586409 non-null int64
# Month            586409 non-null int64
# FracYear         586409 non-null float64
# Secs_from1973    586409 non-null int64
# latitude         586409 non-null float64
# longitude        586409 non-null float64
# mag              586409 non-null float64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 44.7+ MB

# %%
pde.isnull().sum()
# Out:
# Date             0
# ZTime            0
# net              0
# Year             0
# Month            0
# FracYear         0
# Secs_from1973    0
# latitude         0
# longitude        0
# mag              0
# dtype: int64

# %%
# Histogram 
bin_size = 0.5
n_bins = 10/bin_size


plt.hist(pde['mag'])    
# Add title and axis names
plt.title('USGS PDE Earthquake Catalog Histogram')
plt.xlabel('Earthquake Magnitude (M)') #Default is 10 bins
plt.ylabel('Count')
plt.xlim(0,10)

# Show graphic
plt.show()

# %%
sns.set(rc={'figure.figsize':(12,9)})
f,ax = plt.subplots()
sns.distplot(pde['mag'], bins=50, axlabel ='Earthquake Magnitude (M)')
ax.set_title('USGS PDE Earthquake Catalog Histogram')
ax.set_xlabel('Earthquake Magnitude');
ax.set_ylabel('Count');

# %%
pd.crosstab(index=pde['mag'],  # Make a crosstab
                      columns="count")      # Name the count column
# Out:
# col_0  count
# mag
# 0.10       3
# 0.20       1
# 0.30       5
# 0.40       9
# 0.50      10
# 0.60      29
# 0.70      67
# 0.80      86
# 0.90     121
# 1.00     581
# 1.10     306
# 1.20     439
# 1.30     661
# 1.40    1010
# 1.50    1458
# 1.60    1887
# 1.70    2332
# 1.80    2868
# 1.90    3647
# 2.00    4749
# 2.10    5300
# 2.20    5790
# 2.30    5795
# 2.40    5547
# 2.50   13633
# 2.60   14803
# 2.61       1
# 2.70   15496
# 2.75       2
# 2.80   17342
# ...      ...
# 5.50    3812
# 5.60    2806
# 5.70    1852
# 5.80     614
# 5.90     371
# 6.00     264
# 6.10     196
# 6.20     117
# 6.30     117
# 6.40      69
# 6.50      52
# 6.60      51
# 6.70      34
# 6.80      26
# 6.90      28
# 7.00      19
# 7.10      12
# 7.20      12
# 7.30      15
# 7.40      13
# 7.50       5
# 7.60       6
# 7.70       6
# 7.80       6
# 7.90       3
# 8.10       1
# 8.20       1
# 8.60       1
# 8.80       1
# 9.00       1
#
# [92 rows x 1 columns]

# %%
# Scatter plot of Earthquakes vs. Time for The Preliminary Determination of Epicenters (PDE)
 
# Without regression fit:
f,ax = plt.subplots()
sns.regplot(x=pde['FracYear'], y=pde['mag'], fit_reg=False, ax = ax)
ax.set_title('The Preliminary Determination of Epicenters (PDE) Catalog Scatter plot Time vs Earthquake Magnitude')
ax.set_xlabel('Time (Years)');
ax.set_ylabel('Earthquake Magnitude');

# %%
pde.head(2)
# Out:
#          Date     ZTime  net  Year  Month     FracYear  Secs_from1973  \
# 0  01-01-1973  03:46:09  pde  1973      1  1973.076923          13569
# 1  01-01-1973  05:22:29  pde  1973      1  1973.076923          19349
#
#    latitude  longitude  mag
# 0    -9.214    150.634  5.3
# 1   -15.012   -173.958  5.0

# %%
# Loading the The USGS Earthquake catelog data
usgs = pd.read_csv('./data/RevCatAllM_1900-2016.txt')

# %%
usgs = pd.DataFrame(usgs)

# %%
usgs.shape
# Out:
# (468582, 22)

# %%
usgs.head()
# Out:
#                        time   latitude   longitude   depth   mag magType  \
# 0  1987-12-31T23:50:17.520Z  -6.210000  131.410000  33.000  4.70      mb
# 1  1987-12-31T23:22:09.880Z  37.630333 -121.896500   8.210  1.16      md
# 2  1987-12-31T23:03:57.160Z  32.981000 -115.855000   5.139   NaN     NaN
# 3  1987-12-31T23:00:03.980Z  38.806333 -122.796000   0.473  1.16      md
# 4  1987-12-31T22:45:03.560Z  36.715167 -120.731667  -0.467  1.52      md
#
#     nst    gap      dmin    rms net          id                   updated  \
# 0   NaN    NaN       NaN  1.200  us  usp0003bq0  2014-11-07T00:41:25.603Z
# 1  11.0   88.0  0.048650  0.060  nc    nc110428  2016-12-07T16:18:28.710Z
# 2   0.0  190.1       NaN  0.079  ci    ci740053  2016-02-04T05:30:59.270Z
# 3   5.0  232.0  0.001802  0.020  nc   nc1154595  2016-12-07T16:18:24.866Z
# 4  11.0  248.0  0.072070  0.090  nc    nc110426  2016-12-07T16:18:20.723Z
#
#                                 place        type  horizontalError  \
# 0       Kepulauan Tanimbar, Indonesia  earthquake              NaN
# 1  San Francisco Bay area, California  earthquake             0.39
# 2         23km WSW of Westmorland, CA  earthquake              NaN
# 3                 Northern California  earthquake             1.00
# 4                  Central California  earthquake             1.68
#
#    depthError  magError  magNst    status locationSource magSource
# 0         NaN       NaN     6.0  reviewed             us        us
# 1       0.730      0.14    10.0  reviewed             nc        nc
# 2       0.551       NaN     NaN  reviewed             ci        ci
# 3       0.530      0.37     6.0  reviewed             nc        nc
# 4       3.780      0.24     6.0  reviewed             nc        nc

# %%
def toYearFraction(date):
    def sinceEpoch(date): # returns seconds since epoch
        return time.mktime(date.timetuple())
    s = sinceEpoch

    year = date.year
    startOfThisYear = dt2(year=year, month=1, day=1)
    startOfNextYear = dt2(year=year+1, month=1, day=1)

    yearElapsed = s(date) - s(startOfThisYear)
    yearDuration = s(startOfNextYear) - s(startOfThisYear)
    fraction = yearElapsed/yearDuration

    return date.year + fraction
# Taken from the following link on June 20th, 2018 2:30pm
# https://stackoverflow.com/questions/6451655/python-how-to-convert-datetime-dates-to-decimal-years

# %%
# Converting the datestamp from a string to a time datatype.
usgs['time'] = pd.to_datetime(usgs['time'], infer_datetime_format=True)
#usgs['Date_Number']= pd.to_datetime(usgs['time']).map(dt.datetime.toordinal)

usgs['Date_temp']= pd.to_datetime(usgs['time']).apply(lambda x: toYearFraction(x))
#classmethod datetime.strptime(date_string, format)

# grouping right hand with both so that the classification is left handed = 1 or not left handed = 0.
#data['hand'] = data['hand'].apply(lambda x: 0 if x == 3 or x == 1 else 1)

# %%
usgs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 468582 entries, 0 to 468581
# Data columns (total 23 columns):
# time               468582 non-null datetime64[ns]
# latitude           468582 non-null float64
# longitude          468582 non-null float64
# depth              468575 non-null float64
# mag                407777 non-null float64
# magType            407658 non-null object
# nst                352263 non-null float64
# gap                352029 non-null float64
# dmin               262648 non-null float64
# rms                416325 non-null float64
# net                468582 non-null object
# id                 468582 non-null object
# updated            468582 non-null object
# place              468578 non-null object
# type               468582 non-null object
# horizontalError    266225 non-null float64
# depthError         342652 non-null float64
# magError           216235 non-null float64
# magNst             353362 non-null float64
# status             468582 non-null object
# locationSource     468582 non-null object
# magSource          468582 non-null object
# Date_temp          468582 non-null float64
# dtypes: datetime64[ns](1), float64(13), object(9)
# memory usage: 82.2+ MB

# %%
usgs.head()
# Out:
#                      time   latitude   longitude   depth   mag magType   nst  \
# 0 1987-12-31 23:50:17.520  -6.210000  131.410000  33.000  4.70      mb   NaN
# 1 1987-12-31 23:22:09.880  37.630333 -121.896500   8.210  1.16      md  11.0
# 2 1987-12-31 23:03:57.160  32.981000 -115.855000   5.139   NaN     NaN   0.0
# 3 1987-12-31 23:00:03.980  38.806333 -122.796000   0.473  1.16      md   5.0
# 4 1987-12-31 22:45:03.560  36.715167 -120.731667  -0.467  1.52      md  11.0
#
#      gap      dmin    rms net          id                   updated  \
# 0    NaN       NaN  1.200  us  usp0003bq0  2014-11-07T00:41:25.603Z
# 1   88.0  0.048650  0.060  nc    nc110428  2016-12-07T16:18:28.710Z
# 2  190.1       NaN  0.079  ci    ci740053  2016-02-04T05:30:59.270Z
# 3  232.0  0.001802  0.020  nc   nc1154595  2016-12-07T16:18:24.866Z
# 4  248.0  0.072070  0.090  nc    nc110426  2016-12-07T16:18:20.723Z
#
#                                 place        type  horizontalError  \
# 0       Kepulauan Tanimbar, Indonesia  earthquake              NaN
# 1  San Francisco Bay area, California  earthquake             0.39
# 2         23km WSW of Westmorland, CA  earthquake              NaN
# 3                 Northern California  earthquake             1.00
# 4                  Central California  earthquake             1.68
#
#    depthError  magError  magNst    status locationSource magSource  \
# 0         NaN       NaN     6.0  reviewed             us        us
# 1       0.730      0.14    10.0  reviewed             nc        nc
# 2       0.551       NaN     NaN  reviewed             ci        ci
# 3       0.530      0.37     6.0  reviewed             nc        nc
# 4       3.780      0.24     6.0  reviewed             nc        nc
#
#      Date_temp
# 0  1987.999982
# 1  1987.999928
# 2  1987.999893
# 3  1987.999886
# 4  1987.999857

# %%
usgs['mag'].unique();

# %%
usgs[usgs['mag'].isnull()]
# Out:
#                           time   latitude   longitude    depth  mag magType  \
# 2      1987-12-31 23:03:57.160  32.981000 -115.855000    5.139  NaN     NaN
# 6      1987-12-31 22:36:31.630  35.485000 -118.288000    9.412  NaN     NaN
# 8      1987-12-31 21:49:54.850  39.577000   27.782000    6.400  NaN     NaN
# 24     1987-12-31 16:53:05.750  35.912000 -117.749000    6.115  NaN     NaN
# 26     1987-12-31 16:38:59.400 -31.247000  -68.884000  113.900  NaN     NaN
# 36     1987-12-31 13:58:59.930  33.481000 -116.566000   10.935  NaN     NaN
# 42     1987-12-31 12:08:46.900  35.913000 -117.747000    6.035  NaN     NaN
# 49     1987-12-31 11:01:12.600  59.772000 -153.407000  117.000  NaN     NaN
# 58     1987-12-31 08:59:59.290  -6.422000  149.599000   33.000  NaN     NaN
# 73     1987-12-31 07:02:35.980  35.980000 -117.927000    4.226  NaN     NaN
# 74     1987-12-31 06:43:39.240  39.827000   27.456000   10.000  NaN     NaN
# 80     1987-12-31 06:10:13.650  45.578000   26.968000   10.000  NaN     NaN
# 81     1987-12-31 05:48:19.360  33.156000 -115.987000    5.805  NaN     NaN
# 82     1987-12-31 05:39:57.850  33.047000 -116.419000    5.163  NaN     NaN
# 84     1987-12-31 05:16:18.000  35.980000 -117.927000    4.426  NaN     NaN
# 93     1987-12-31 03:12:58.920  59.815000 -152.246000   70.000  NaN     NaN
# 94     1987-12-31 03:07:12.990  11.368000   41.752000   10.000  NaN     NaN
# 96     1987-12-31 03:01:10.540  36.101000 -117.866000    4.659  NaN     NaN
# 97     1987-12-31 03:00:43.650  36.093000 -117.859000    2.919  NaN     NaN
# 100    1987-12-31 02:14:37.700  33.034000 -116.420000    6.753  NaN     NaN
# 104    1987-12-31 01:10:58.670  36.090000 -117.859000    2.865  NaN     NaN
# 105    1987-12-31 00:54:34.450  33.260000 -116.165000    5.402  NaN     NaN
# 108    1987-12-31 00:36:03.580  35.547000 -118.260000    4.053  NaN     NaN
# 117    1987-12-30 23:09:16.670  33.555000 -117.188000   -0.412  NaN     NaN
# 121    1987-12-30 22:32:43.430  62.256000 -151.156000   84.400  NaN     NaN
# 122    1987-12-30 22:18:28.860  58.111000 -142.836000   10.000  NaN     NaN
# 130    1987-12-30 20:42:09.780  35.670000 -118.090000   13.526  NaN     NaN
# 133    1987-12-30 19:44:01.720  36.101000 -117.865000    4.769  NaN     NaN
# 139    1987-12-30 18:32:09.890  35.911000 -117.757000    7.864  NaN     NaN
# 144    1987-12-30 17:33:29.720  33.569000 -117.205000    5.098  NaN     NaN
# ...                        ...        ...         ...      ...  ...     ...
# 448886 1973-01-05 09:07:31.800   5.537000  126.430000   33.000  NaN     NaN
# 448897 1973-01-04 19:11:16.400 -10.391000  123.358000   33.000  NaN     NaN
# 448903 1973-01-04 04:08:01.700 -49.745000  155.072000   33.000  NaN     NaN
# 448937 1973-01-01 22:33:01.600 -44.303000  167.154000   61.000  NaN     NaN
# 454318 1966-07-11 20:40:19.060  35.857833 -120.390000    6.040  NaN     NaN
# 454381 1966-07-08 01:33:28.810  35.776500 -120.326167    3.277  NaN     NaN
# 454477 1966-07-03 04:18:30.570  35.867667 -120.392667   -0.439  NaN     NaN
# 454488 1966-07-02 17:23:15.350  35.810833 -120.340333   11.550  NaN     NaN
# 454489 1966-07-02 15:21:20.710  36.771167 -120.752500    4.505  NaN     NaN
# 454502 1966-07-02 09:40:09.180  35.786500 -120.329500    3.339  NaN     NaN
# 454504 1966-07-02 08:28:18.890  35.770500 -120.317167    3.970  NaN     NaN
# 454505 1966-07-02 08:13:09.280  35.794333 -120.340333    8.370  NaN     NaN
# 454506 1966-07-02 07:58:27.320  35.785833 -120.335000    4.238  NaN     NaN
# 454538 1966-07-01 14:43:22.420  35.813333 -120.366833    4.060  NaN     NaN
# 456645 1958-10-16 19:31:12.650  32.871833 -115.477000    6.000  NaN     NaN
# 456646 1958-10-16 19:18:57.200  32.881667 -115.466500    6.000  NaN     NaN
# 457469 1956-03-10 15:07:04.770  30.764000 -114.277667    6.000  NaN     NaN
# 460512 1950-01-14 19:53:01.700  39.942000 -123.410000    6.000  NaN     NaN
# 461069 1948-12-14 09:55:34.810  33.917167 -116.381167    6.000  NaN     NaN
# 461886 1947-05-02 06:17:24.750  34.975167 -116.590167    6.000  NaN     NaN
# 462802 1944-11-04 08:12:03.120  36.333333 -120.083000    6.000  NaN     NaN
# 464123 1940-05-19 05:51:09.540  32.833000 -115.500000    6.000  NaN     NaN
# 468055 1933-03-09 09:13:51.140  33.687000 -117.922000    6.000  NaN     NaN
# 468059 1933-03-05 12:07:01.990  34.293000 -116.842000    6.000  NaN     NaN
# 468060 1933-03-05 11:26:01.920  33.115000 -118.528000    6.000  NaN     NaN
# 468549 1932-01-25 21:16:29.640  31.530667 -116.400167    6.000  NaN     NaN
# 468550 1932-01-25 15:34:12.490  34.047000 -118.002500    6.000  NaN     NaN
# 468552 1932-01-23 12:01:36.410  31.656833 -115.481500    6.000  NaN     NaN
# 468560 1932-01-16 08:06:39.600  33.884667 -118.112833    6.000  NaN     NaN
# 468580 1932-01-01 23:52:08.130  34.130000 -117.993000    6.000  NaN     NaN
#
#         nst    gap     dmin    rms net          id                   updated  \
# 2       0.0  190.1      NaN  0.079  ci    ci740053  2016-02-04T05:30:59.270Z
# 6       0.0  114.6      NaN  0.071  ci    ci740051  2016-02-03T21:41:01.500Z
# 8       NaN    NaN      NaN  0.700  us  usp0003bpz  2014-11-07T00:41:25.600Z
# 24      0.0   67.8      NaN  0.070  ci    ci740026  2016-02-04T03:35:11.010Z
# 26      NaN    NaN      NaN  1.300  us  usp0003bpt  2014-11-07T00:41:25.586Z
# 36      0.0   96.7      NaN  0.132  ci    ci740021  2016-02-04T01:38:26.550Z
# 42      0.0   68.1      NaN  0.081  ci    ci740019  2016-02-03T23:00:39.870Z
# 49      NaN    NaN      NaN    NaN  us  usp0003bpp  2014-11-07T00:41:25.577Z
# 58      NaN    NaN      NaN  1.300  us  usp0003bpm  2014-11-07T00:41:25.573Z
# 73      0.0   84.7      NaN  0.048  ci    ci740006  2016-02-03T21:41:00.140Z
# 74      NaN    NaN      NaN  0.900  us  usp0003bpj  2014-11-07T00:41:25.568Z
# 80      NaN    NaN      NaN  0.900  us  usp0003bpg  2014-11-07T00:41:25.552Z
# 81      0.0  150.7      NaN  0.035  ci    ci740003  2016-02-04T00:16:45.870Z
# 82      0.0  137.2      NaN  0.035  ci    ci740002  2016-02-03T19:42:33.850Z
# 84      0.0   84.6      NaN  0.045  ci    ci739998  2016-02-03T20:22:09.530Z
# 93      NaN    NaN      NaN    NaN  us  usp0003bpc  2014-11-07T00:41:25.541Z
# 94      NaN    NaN      NaN  0.200  us  usp0003bpb  2014-11-07T00:41:25.540Z
# 96      0.0  175.2      NaN  0.026  ci    ci138132  2016-02-03T21:01:32.260Z
# 97      0.0   91.6      NaN  0.039  ci    ci739995  2016-02-04T02:56:16.320Z
# 100     0.0  145.0      NaN  0.012  ci    ci739993  2016-02-04T02:16:48.050Z
# 104     0.0   91.5      NaN  0.037  ci    ci739988  2016-02-04T05:30:58.340Z
# 105     0.0  131.8      NaN  0.058  ci    ci739986  2016-02-03T23:38:56.700Z
# 108     0.0   86.6      NaN  0.038  ci    ci739984  2016-02-03T22:21:11.690Z
# 117     0.0  168.7      NaN  0.075  ci    ci739978  2016-02-04T02:56:15.410Z
# 121     NaN    NaN      NaN    NaN  us  usp0003bp5  2014-11-07T00:41:25.517Z
# 122     NaN    NaN      NaN    NaN  us  usp0003bp4  2014-11-07T00:41:25.516Z
# 130     0.0   81.4      NaN  0.047  ci    ci739969  2016-02-04T03:35:08.460Z
# 133     0.0  173.9      NaN  0.017  ci    ci739966  2016-02-04T02:16:47.600Z
# 139     0.0   66.6      NaN  0.056  ci    ci739960  2016-02-04T02:56:14.120Z
# 144     0.0  166.2      NaN  0.030  ci    ci739953  2016-02-03T20:22:08.140Z
# ...     ...    ...      ...    ...  ..         ...                       ...
# 448886  NaN    NaN      NaN    NaN  us  usp000001a  2014-11-06T23:21:07.321Z
# 448897  NaN    NaN      NaN    NaN  us  usp0000013  2014-11-06T23:21:07.299Z
# 448903  NaN    NaN      NaN    NaN  us  usp000000y  2014-11-06T23:21:07.282Z
# 448937  NaN    NaN      NaN    NaN  us  usp0000007  2014-11-06T23:21:07.206Z
# 454318  8.0  296.0  0.07207  0.010  nc   nc1000244  2016-12-08T19:08:46.011Z
# 454381  5.0   95.0  0.02883  0.140  nc   nc1000183  2016-12-08T19:03:49.211Z
# 454477  5.0  324.0  0.04865  0.040  nc   nc1000088  2016-12-08T18:56:59.942Z
# 454488  4.0  287.0  0.02432  0.000  nc   nc1000077  2016-12-08T18:56:10.912Z
# 454489  5.0  355.0  0.99370  0.320  nc   nc1000076  2016-12-08T18:56:06.769Z
# 454502  4.0  139.0  0.02342  0.000  nc   nc1000063  2016-12-08T18:55:11.427Z
# 454504  6.0   99.0  0.01532  0.080  nc   nc1000061  2016-12-08T18:55:02.823Z
# 454505  6.0  174.0  0.01441  0.020  nc   nc1000060  2016-12-08T18:54:56.825Z
# 454506  7.0   81.0  0.01892  0.220  nc   nc1000059  2016-12-08T18:54:52.507Z
# 454538  4.0  312.0  0.02342  0.010  nc   nc1000027  2016-12-08T18:52:28.652Z
# 456645  3.0  269.0  0.84420  0.380  ci   ci3296799  2016-04-02T00:10:32.485Z
# 456646  3.0  269.0  0.83600  0.560  ci   ci3296798  2016-04-01T20:55:46.356Z
# 457469  6.0  348.0  2.79500  5.720  ci   ci3294982  2016-04-02T00:10:31.267Z
# 460512  0.0    0.0  4.98200  0.000  ci   ci3362072  2016-01-28T18:25:48.340Z
# 461069  3.0  293.0  0.69090  0.300  ci   ci3356406  2016-04-02T06:36:16.330Z
# 461886  3.0  310.0  1.17500  0.600  ci   ci3358792  2016-04-02T09:52:08.968Z
# 462802  6.0  253.0  1.65400  2.180  ci   ci3362480  2016-04-01T20:53:10.002Z
# 464123  0.0  330.5  1.47700  2.055  ci   ci3365284  2016-01-28T01:31:55.010Z
# 468055  0.0  190.3  0.50480  0.068  ci   ci3359740  2016-01-27T18:47:20.040Z
# 468059  0.0  360.0  1.11100  0.000  ci   ci3359733  2016-01-27T18:34:23.080Z
# 468060  0.0  360.0  1.07300  0.000  ci   ci3359732  2016-01-27T18:25:51.870Z
# 468549  2.0  350.0  1.51300  0.030  ci   ci3358498  2016-04-01T20:53:35.167Z
# 468550  2.0  320.0  0.17270  0.130  ci   ci3358495  2016-04-02T19:15:05.966Z
# 468552  2.0  343.0  1.92400  0.070  ci   ci3358489  2016-04-02T19:15:04.544Z
# 468560  2.0  343.0  0.26750  0.510  ci   ci3358446  2016-04-02T16:10:46.241Z
# 468580  0.0  307.1  0.10800  0.067  ci   ci3358386  2016-01-27T18:38:27.130Z
#
#                                             place        type  \
# 2                     23km WSW of Westmorland, CA  earthquake
# 6                         22km ESE of Bodfish, CA  earthquake
# 8                                  western Turkey  earthquake
# 24                      14km E of Little Lake, CA  earthquake
# 26                            San Juan, Argentina  earthquake
# 36                            13km SE of Anza, CA  earthquake
# 42                      15km E of Little Lake, CA  earthquake
# 49                                Southern Alaska  earthquake
# 58           New Britain region, Papua New Guinea  earthquake
# 73                     5km NNW of Little Lake, CA  earthquake
# 74                                 western Turkey  earthquake
# 80                                        Romania  earthquake
# 81                   14km E of Ocotillo Wells, CA  earthquake
# 82                         17km ESE of Julian, CA  earthquake
# 84                     5km NNW of Little Lake, CA  earthquake
# 93                                Southern Alaska  earthquake
# 94                                       Ethiopia  earthquake
# 96                   10km NE of Coso Junction, CA  earthquake
# 97                  10km ENE of Coso Junction, CA  earthquake
# 100                        18km ESE of Julian, CA  earthquake
# 104                 10km ENE of Coso Junction, CA  earthquake
# 105                13km NNW of Ocotillo Wells, CA  earthquake
# 108                 21km ESE of Lake Isabella, CA  earthquake
# 117                         2km E of Murrieta, CA  earthquake
# 121                                Central Alaska  earthquake
# 122                                Gulf of Alaska  earthquake
# 130                        25km W of Inyokern, CA  earthquake
# 133                  10km NE of Coso Junction, CA  earthquake
# 139                   14km ESE of Little Lake, CA  earthquake
# 144                       2km NNE of Murrieta, CA  earthquake
# ...                                           ...         ...
# 448886                      Mindanao, Philippines  earthquake
# 448897                    Timor region, Indonesia  earthquake
# 448903                  north of Macquarie Island  earthquake
# 448937                South Island of New Zealand  earthquake
# 454318                         Central California  earthquake
# 454381                         Central California  earthquake
# 454477                         Central California  earthquake
# 454488                         Central California  earthquake
# 454489                         Central California  earthquake
# 454502                         Central California  earthquake
# 454504                         Central California  earthquake
# 454505                         Central California  earthquake
# 454506                         Central California  earthquake
# 454538                         Central California  earthquake
# 456645                    9km ENE of Imperial, CA  earthquake
# 456646                   10km ENE of Imperial, CA  earthquake
# 457469   173km SSE of Estacion Coahuila, B.C., MX  earthquake
# 460512                      22km NW of Covelo, CA  earthquake
# 461069               11km N of Thousand Palms, CA  earthquake
# 461886                 33km SSE of Fort Irwin, CA  earthquake
# 462802                        15km N of Huron, CA  earthquake
# 464123                    7km ESE of Imperial, CA  earthquake
# 468055                  3km NNW of Costa Mesa, CA  earthquake
# 468059                 4km N of Big Bear City, CA  earthquake
# 468060   12km NE of San Clemente Is. (NW tip), CA  earthquake
# 468549             26km SE of Maneadero, B.C., MX  earthquake
# 468550              2km NW of Avocado Heights, CA  earthquake
# 468552  70km SSW of Alberto Oviedo Mota, B.C., MX  earthquake
# 468560                   0km NE of Bellflower, CA  earthquake
# 468580                       2km SW of Duarte, CA  earthquake
#
#         horizontalError  depthError  magError  magNst    status  \
# 2                   NaN       0.551       NaN     NaN  reviewed
# 6                   NaN       0.406       NaN     NaN  reviewed
# 8                   NaN       4.600       NaN     NaN  reviewed
# 24                  NaN       0.051       NaN     NaN  reviewed
# 26                  NaN      19.300       NaN     NaN  reviewed
# 36                  NaN       0.166       NaN     NaN  reviewed
# 42                  NaN       0.032       NaN     NaN  reviewed
# 49                  NaN         NaN       NaN     NaN  reviewed
# 58                  NaN         NaN       NaN     NaN  reviewed
# 73                  NaN       0.568       NaN     NaN  reviewed
# 74                  NaN         NaN       NaN     NaN  reviewed
# 80                  NaN         NaN       NaN     NaN  reviewed
# 81                  NaN         NaN       NaN     NaN  reviewed
# 82                  NaN       4.440       NaN     NaN  reviewed
# 84                  NaN       0.281       NaN     NaN  reviewed
# 93                  NaN         NaN       NaN     NaN  reviewed
# 94                  NaN         NaN       NaN     NaN  reviewed
# 96                  NaN       0.172       NaN     NaN  reviewed
# 97                  NaN       0.034       NaN     NaN  reviewed
# 100                 NaN       0.888       NaN     NaN  reviewed
# 104                 NaN       0.022       NaN     NaN  reviewed
# 105                 NaN       4.445       NaN     NaN  reviewed
# 108                 NaN       0.054       NaN     NaN  reviewed
# 117                 NaN       1.442       NaN     NaN  reviewed
# 121                 NaN         NaN       NaN     NaN  reviewed
# 122                 NaN         NaN       NaN     NaN  reviewed
# 130                 NaN       0.032       NaN     NaN  reviewed
# 133                 NaN       0.702       NaN     NaN  reviewed
# 139                 NaN       0.081       NaN     NaN  reviewed
# 144                 NaN         NaN       NaN     NaN  reviewed
# ...                 ...         ...       ...     ...       ...
# 448886              NaN         NaN       NaN     NaN  reviewed
# 448897              NaN         NaN       NaN     NaN  reviewed
# 448903              NaN         NaN       NaN     NaN  reviewed
# 448937              NaN         NaN       NaN     NaN  reviewed
# 454318             3.24       1.100       NaN     NaN  reviewed
# 454381             0.66       1.680       NaN     NaN  reviewed
# 454477             3.92       5.680       NaN     NaN  reviewed
# 454488             2.90       3.270       NaN     NaN  reviewed
# 454489            23.22      19.950       NaN     NaN  reviewed
# 454502             0.53       1.260       NaN     NaN  reviewed
# 454504             0.52       1.120       NaN     NaN  reviewed
# 454505             1.13       1.780       NaN     NaN  reviewed
# 454506             1.01       2.330       NaN     NaN  reviewed
# 454538             6.99       2.840       NaN     NaN  reviewed
# 456645             3.29      31.610       NaN     NaN  reviewed
# 456646             4.72      31.610       NaN     NaN  reviewed
# 457469            99.00      31.610       NaN     NaN  reviewed
# 460512              NaN         NaN       NaN     NaN  reviewed
# 461069             2.42      31.610       NaN     NaN  reviewed
# 461886             4.62      31.610       NaN     NaN  reviewed
# 462802            99.00      31.610       NaN     NaN  reviewed
# 464123              NaN         NaN       NaN     NaN  reviewed
# 468055              NaN         NaN       NaN     NaN  reviewed
# 468059              NaN         NaN       NaN     NaN  reviewed
# 468060              NaN         NaN       NaN     NaN  reviewed
# 468549             3.38      31.610       NaN     NaN  reviewed
# 468550             1.11      31.610       NaN     NaN  reviewed
# 468552             2.87      31.610       NaN     NaN  reviewed
# 468560             6.18      31.610       NaN     NaN  reviewed
# 468580              NaN         NaN       NaN     NaN  reviewed
#
#        locationSource magSource    Date_temp
# 2                  ci        ci  1987.999893
# 6                  ci        ci  1987.999841
# 8                  us        us  1987.999752
# 24                 ci        ci  1987.999188
# 26                 us        us  1987.999161
# 36                 ci        ci  1987.998857
# 42                 ci        ci  1987.998647
# 49                ags        us  1987.998518
# 58                 us        us  1987.998288
# 73                 ci        ci  1987.998064
# 74                 us        us  1987.998028
# 80                 us        us  1987.997965
# 81                 ci        ci  1987.997923
# 82                 ci        ci  1987.997907
# 84                 ci        ci  1987.997862
# 93                ags        us  1987.997627
# 94                 us        us  1987.997616
# 96                 ci        ci  1987.997605
# 97                 ci        ci  1987.997604
# 100                ci        ci  1987.997516
# 104                ci        ci  1987.997395
# 105                ci        ci  1987.997364
# 108                ci        ci  1987.997329
# 117                ci        ci  1987.997164
# 121               ags        us  1987.997094
# 122               ags        us  1987.997067
# 130                ci        ci  1987.996884
# 133                ci        ci  1987.996773
# 139                ci        ci  1987.996637
# 144                ci        ci  1987.996525
# ...               ...       ...          ...
# 448886             us        us  1973.012001
# 448897             us        us  1973.010410
# 448903             us        us  1973.008691
# 448937             us        us  1973.002574
# 454318             nc        nc  1966.525533
# 454381             nc        nc  1966.515132
# 454477             nc        nc  1966.501748
# 454488             nc        nc  1966.500501
# 454489             nc        nc  1966.500269
# 454502             nc        nc  1966.499620
# 454504             nc        nc  1966.499483
# 454505             nc        nc  1966.499454
# 454506             nc        nc  1966.499426
# 454538             nc        nc  1966.497457
# 456645             ci        ci  1958.791155
# 456646             ci        ci  1958.791132
# 457469             ci        ci  1956.190246
# 460512             ci        ci  1950.037886
# 461069             ci        ci  1948.951950
# 461886             ci        ci  1947.332111
# 462802             ci        ci  1944.842464
# 464123             ci        ci  1940.380334
# 468055             ci        ci  1933.184615
# 468059             ci        ci  1933.173986
# 468060             ci        ci  1933.173908
# 468549             ci        ci  1932.067996
# 468550             ci        ci  1932.067346
# 468552             ci        ci  1932.061478
# 468560             ci        ci  1932.041907
# 468580             ci        ci  1932.002717
#
# [60805 rows x 23 columns]

# %%
eq_usgs = usgs[usgs['mag'].notnull()]
eq_usgs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 407777 entries, 0 to 468581
# Data columns (total 23 columns):
# time               407777 non-null datetime64[ns]
# latitude           407777 non-null float64
# longitude          407777 non-null float64
# depth              407770 non-null float64
# mag                407777 non-null float64
# magType            407658 non-null object
# nst                317291 non-null float64
# gap                317057 non-null float64
# dmin               253135 non-null float64
# rms                364405 non-null float64
# net                407777 non-null object
# id                 407777 non-null object
# updated            407777 non-null object
# place              407773 non-null object
# type               407777 non-null object
# horizontalError    261792 non-null float64
# depthError         313028 non-null float64
# magError           216235 non-null float64
# magNst             353362 non-null float64
# status             407777 non-null object
# locationSource     407777 non-null object
# magSource          407777 non-null object
# Date_temp          407777 non-null float64
# dtypes: datetime64[ns](1), float64(13), object(9)
# memory usage: 74.7+ MB

# %%
eq_usgs['depth'].isnull().sum()
# Out:
# 7

# %%
eq_usgs[eq_usgs['depth'].isnull()]
# Out:
#                           time  latitude  longitude  depth  mag magType  nst  \
# 432886 1974-12-03 08:25:00.000     33.95     -82.50    NaN  3.6      ml  NaN
# 433145 1974-11-25 23:34:05.100     40.30     -87.40    NaN  2.4      lg  NaN
# 433751 1974-11-05 03:00:00.000     33.73     -82.22    NaN  3.7      ml  NaN
# 433962 1974-10-28 11:33:00.000     33.79     -81.92    NaN  3.0      ml  NaN
# 434498 1974-10-09 20:04:34.000     42.20     -71.50    NaN  1.5     NaN  NaN
# 434718 1974-10-01 06:36:21.000     41.70     -71.50    NaN  2.5      ml  NaN
# 437084 1974-07-14 11:14:38.000     47.60    -120.70    NaN  3.3     NaN  NaN
#
#         gap  dmin  rms net          id                   updated  \
# 432886  NaN   NaN  NaN  us  usp00008zm  2014-11-06T23:21:27.653Z
# 433145  NaN   NaN  NaN  us  usp00008ws  2014-11-06T23:21:27.552Z
# 433751  NaN   NaN  NaN  us  usp00008pg  2014-11-06T23:21:27.157Z
# 433962  NaN   NaN  NaN  us  usp00008kh  2014-11-06T23:21:27.052Z
# 434498  NaN   NaN  NaN  us  usp00008bb  2014-11-06T23:21:26.760Z
# 434718  NaN   NaN  NaN  us  usp000087u  2014-11-06T23:21:26.629Z
# 437084  NaN   NaN  NaN  us  usp0000755  2014-11-06T23:21:25.225Z
#
#                        place        type  horizontalError  depthError  \
# 432886          Georgia, USA  earthquake              NaN         NaN
# 433145               Indiana  earthquake              NaN         NaN
# 433751          Georgia, USA  earthquake              NaN         NaN
# 433962        South Carolina  earthquake              NaN         NaN
# 434498  southern New England  earthquake              NaN         NaN
# 434718  southern New England  earthquake              NaN         NaN
# 437084            Washington  earthquake              NaN         NaN
#
#         magError  magNst    status locationSource magSource    Date_temp
# 432886       NaN     NaN  reviewed              m       csc  1974.921509
# 433145       NaN     NaN  reviewed              j       slm  1974.901321
# 433751       NaN     NaN  reviewed              m       csc  1974.844178
# 433962       NaN     NaN  reviewed              m       csc  1974.823236
# 434498       NaN     NaN  reviewed              c       san  1974.772041
# 434718       NaN     NaN  reviewed              c       san  1974.748585
# 437084       NaN     NaN  reviewed              w       sea  1974.532676

# %%
eq_usgs = eq_usgs[eq_usgs['depth'].notnull()]

# %%
eq_usgs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 407770 entries, 0 to 468581
# Data columns (total 23 columns):
# time               407770 non-null datetime64[ns]
# latitude           407770 non-null float64
# longitude          407770 non-null float64
# depth              407770 non-null float64
# mag                407770 non-null float64
# magType            407653 non-null object
# nst                317291 non-null float64
# gap                317057 non-null float64
# dmin               253135 non-null float64
# rms                364405 non-null float64
# net                407770 non-null object
# id                 407770 non-null object
# updated            407770 non-null object
# place              407766 non-null object
# type               407770 non-null object
# horizontalError    261792 non-null float64
# depthError         313028 non-null float64
# magError           216235 non-null float64
# magNst             353362 non-null float64
# status             407770 non-null object
# locationSource     407770 non-null object
# magSource          407770 non-null object
# Date_temp          407770 non-null float64
# dtypes: datetime64[ns](1), float64(13), object(9)
# memory usage: 74.7+ MB

# %%
# Histogram 

plt.hist(eq_usgs['mag'])    
# Add title and axis names
plt.title('USGS Earthquake Catalog Histogram')
plt.xlabel('Earthquake Magnitude (M)') #Default is 10 bins
plt.ylabel('Count')
plt.xlim(0,10)

# Show graphic
plt.show()

# %%
sns.set(rc={'figure.figsize':(12,9)})
f,ax = plt.subplots()
sns.distplot(eq_usgs['mag'], bins=50, axlabel ='Earthquake Magnitude (M)')
ax.set_title('USGS Earthquake Catalog Histogram')
ax.set_xlabel('Earthquake Magnitude');
ax.set_ylabel('Count');

# %%
pd.crosstab(index=eq_usgs['mag'],  # Make a crosstab
                      columns="count")      # Name the count column
# Out:
# col_0  count
# mag
# -1.10      5
# -1.00     26
# -0.90      7
# -0.80     22
# -0.70      7
# -0.60     36
# -0.50     69
# -0.40     89
# -0.30    144
# -0.20    143
# -0.10    233
# -0.04      1
#  0.00    371
#  0.01     14
#  0.02     19
#  0.03     16
#  0.04     13
#  0.05     11
#  0.06     22
#  0.07      8
#  0.08     20
#  0.09     20
#  0.10    376
#  0.11     34
#  0.12     45
#  0.13     94
#  0.14    139
#  0.15    114
#  0.16     98
#  0.17     78
# ...      ...
#  6.09      1
#  6.10    281
#  6.12      1
#  6.20    208
#  6.30    165
#  6.31      1
#  6.33      1
#  6.35      2
#  6.40    154
#  6.42      1
#  6.43      1
#  6.47      1
#  6.50    119
#  6.60     69
#  6.70     78
#  6.80     60
#  6.90     44
#  7.00     41
#  7.10     30
#  7.20     26
#  7.30     10
#  7.40     17
#  7.50     13
#  7.60     10
#  7.70      8
#  7.80      2
#  7.90      7
#  8.00      4
#  8.50      1
#  8.80      1
#
# [614 rows x 1 columns]

# %%
place = pd.crosstab(index=eq_usgs['place'],  # Make a crosstab
                      columns="count")      # Name the count column

# %%
place
# Out:
# col_0                                   count
# place
# 0km E of Anza, CA                           4
# 0km E of Compton, CA                        1
# 0km E of Desert Hot Springs, CA             1
# 0km E of El Centro, CA                      1
# 0km E of Granada Hills, CA                  1
# 0km E of Guadalupe Victoria, B.C., MX       1
# 0km E of Hemet, CA                          1
# 0km E of Kernville, CA                      1
# 0km E of Lakewood, CA                       1
# 0km E of Loma Linda, CA                     3
# 0km E of Lomita, CA                         1
# 0km E of Muscoy, CA                         1
# 0km E of Palomar Observatory, CA            1
# 0km E of San Gabriel, CA                    1
# 0km E of Temecula, CA                       1
# 0km E of Vincent, CA                        1
# 0km ENE of Anza, CA                         1
# 0km ENE of Brawley, CA                      2
# 0km ENE of Colton, CA                       2
# 0km ENE of Cypress, CA                      1
# 0km ENE of Diamond Bar, CA                  1
# 0km ENE of East Los Angeles, CA             1
# 0km ENE of El Sauzal, B.C., MX              1
# 0km ENE of Estacion Coahuila, B.C., MX      1
# 0km ENE of Inglewood, CA                    1
# 0km ENE of Loma Linda, CA                   2
# 0km ENE of Lomita, CA                       2
# 0km ENE of Ocotillo Wells, CA               1
# 0km ENE of Palm Springs, CA                 1
# 0km ENE of Seal Beach, CA                   1
# ...                                       ...
# southwestern Sakha, Russia                  6
# southwestern Siberia, Russia               11
# west of Australia                           1
# west of Dominica, Leeward Islands           1
# west of Gibraltar                          11
# west of Guadeloupe, Leeward Islands         1
# west of Macquarie Island                  111
# west of Vancouver Island                    1
# west of the Bonin Islands, Japan            2
# west of the Galapagos Islands              24
# west of the Malay Peninsula, Thailand       1
# west of the Mariana Islands                 2
# west of the Queen Charlotte Islands         2
# western Afghanistan                        12
# western Greenland                           3
# western Honshu, Japan                      68
# western Indian-Antarctic Ridge             84
# western Iran                              180
# western Kentucky                            1
# western Mediterranean Sea                  26
# western Mongolia                           18
# western Montana                           237
# western Nei Mongol, China                  11
# western Saudi Arabia                        1
# western Sichuan, China                     73
# western Texas                              17
# western Turkey                            420
# western Uzbekistan                        166
# western Xizang                            209
# western Xizang-India border region         22
#
# [26183 rows x 1 columns]

# %%
eq_usgs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 407770 entries, 0 to 468581
# Data columns (total 23 columns):
# time               407770 non-null datetime64[ns]
# latitude           407770 non-null float64
# longitude          407770 non-null float64
# depth              407770 non-null float64
# mag                407770 non-null float64
# magType            407653 non-null object
# nst                317291 non-null float64
# gap                317057 non-null float64
# dmin               253135 non-null float64
# rms                364405 non-null float64
# net                407770 non-null object
# id                 407770 non-null object
# updated            407770 non-null object
# place              407766 non-null object
# type               407770 non-null object
# horizontalError    261792 non-null float64
# depthError         313028 non-null float64
# magError           216235 non-null float64
# magNst             353362 non-null float64
# status             407770 non-null object
# locationSource     407770 non-null object
# magSource          407770 non-null object
# Date_temp          407770 non-null float64
# dtypes: datetime64[ns](1), float64(13), object(9)
# memory usage: 74.7+ MB

# %%
# Scatter plot of Earthquakes vs. Time for The USGS
 
# Without regression fit:
f,ax = plt.subplots()
sns.regplot(x=usgs['Date_temp'], y=usgs['mag'], fit_reg=False, ax = ax)
ax.set_title('The USGS Catalog Scatter plot Time vs Earthquake Magnitude')
ax.set_xlabel('Time (Years)');
ax.set_ylabel('Earthquake Magnitude');

# %%
# Scatter plot of Earthquakes vs. Time for The USGS
 
# Without regression fit:
f,ax = plt.subplots()
sns.regplot(x=eq_usgs['Date_temp'], y=eq_usgs['mag'], fit_reg=False, ax = ax)
ax.set_title('The USGS Catalog Scatter plot Time vs Earthquake Magnitude')
ax.set_xlabel('Time (Years)');
ax.set_ylabel('Earthquake Magnitude');

# %%
eq_usgs.head(2)
# Out:
#                      time   latitude  longitude  depth   mag magType   nst  \
# 0 1987-12-31 23:50:17.520  -6.210000   131.4100  33.00  4.70      mb   NaN
# 1 1987-12-31 23:22:09.880  37.630333  -121.8965   8.21  1.16      md  11.0
#
#     gap     dmin   rms net          id                   updated  \
# 0   NaN      NaN  1.20  us  usp0003bq0  2014-11-07T00:41:25.603Z
# 1  88.0  0.04865  0.06  nc    nc110428  2016-12-07T16:18:28.710Z
#
#                                 place        type  horizontalError  \
# 0       Kepulauan Tanimbar, Indonesia  earthquake              NaN
# 1  San Francisco Bay area, California  earthquake             0.39
#
#    depthError  magError  magNst    status locationSource magSource  \
# 0         NaN       NaN     6.0  reviewed             us        us
# 1        0.73      0.14    10.0  reviewed             nc        nc
#
#      Date_temp
# 0  1987.999982
# 1  1987.999928

# %%
my_cols = ['EVENTID','AUTHOR','DATE','TIME','LAT','LON','DEPTH','DEPFIX',
           'AUTHOR','TYPE','MAG',
           'AUTHOR2','TYPE2','MAG2',
           'AUTHOR3','TYPE3','MAG3',
           'AUTHOR4','TYPE4','MAG4',
           'AUTHOR5','TYPE5','MAG5',
           'AUTHOR6','TYPE6','MAG6',
           'AUTHOR7','TYPE7','MAG7',
           'AUTHOR8','TYPE8','MAG8',
           'AUTHOR9','TYPE9','MAG9',
           'AUTHOR10','TYPE10','MAG10',
           'AUTHOR11','TYPE11','MAG11',
           'AUTHOR12','TYPE12','MAG12',
           'AUTHOR13','TYPE13','MAG13',
           'AUTHOR14','TYPE14','MAG14',
           'AUTHOR15','TYPE15','MAG15',
           'AUTHOR16','TYPE16','MAG16',
           'AUTHOR17','TYPE17','MAG17',
           'AUTHOR18','TYPE18','MAG18',
           'AUTHOR19','TYPE19','MAG19',
           'AUTHOR20','TYPE20','MAG20',
           'AUTHOR21','TYPE21','MAG21',
           'AUTHOR22','TYPE22','MAG22',
           'AUTHOR23','TYPE23','MAG23',
           'AUTHOR24','TYPE24','MAG24',
           'AUTHOR25','TYPE25','MAG25',
           'AUTHOR26','TYPE26','MAG26',
           'AUTHOR27','TYPE27','MAG27',
           'AUTHOR28','TYPE28','MAG28',
           'AUTHOR29','TYPE29','MAG29',
           'AUTHOR30','TYPE30','MAG30',
           'AUTHOR31','TYPE31','MAG31',
           'AUTHOR32','TYPE32','MAG32',
           'AUTHOR33','TYPE33','MAG33',
           'AUTHOR34','TYPE34','MAG34',
           'AUTHOR35','TYPE35','MAG35',
           'AUTHOR36','TYPE36','MAG36',
           'AUTHOR37','TYPE37','MAG37',
           'AUTHOR38','TYPE38','MAG38',
           'AUTHOR39','TYPE39','MAG39',
           'AUTHOR40','TYPE40','MAG40',
           'AUTHOR41','TYPE41','MAG41',
           'AUTHOR42','TYPE42','MAG42',
           'AUTHOR43','TYPE43','MAG43',
           'AUTHOR44','TYPE44','MAG44',
           'AUTHOR45','TYPE45','MAG45',
           'AUTHOR46','TYPE46','MAG46',
           'AUTHOR47','TYPE47','MAG47',
           'AUTHOR48','TYPE48','MAG48',
           'AUTHOR49','TYPE49','MAG49',
           'AUTHOR50','TYPE50','MAG50',
           'AUTHOR51','TYPE51','MAG51',
           'AUTHOR52','TYPE52','MAG52',
           'AUTHOR53','TYPE53','MAG53',
           'AUTHOR54','TYPE54','MAG54',
           'AUTHOR55','TYPE55','MAG55',
           'AUTHOR56','TYPE56','MAG56',
           'AUTHOR57','TYPE57','MAG57',
           'AUTHOR58','TYPE58','MAG58',
           'AUTHOR59','TYPE59','MAG59',
           'AUTHOR60','TYPE60','MAG60',
           'AUTHOR61','TYPE61','MAG61',
           'AUTHOR62','TYPE62','MAG62',
           'AUTHOR63','TYPE63','MAG63',
           'AUTHOR64','TYPE64','MAG64',
           'AUTHOR65','TYPE65','MAG65',
           'AUTHOR66','TYPE66','MAG66',
           'AUTHOR67','TYPE67','MAG67',
           'AUTHOR68','TYPE68','MAG68'] #,'AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG','AUTHOR','TYPE','MAG'] # Put list of header names here.

# %%
# Loading the ISC Bullitin data, 2nd attempt.
isc = pd.read_csv("./data/ISC_Rev_allM_1904_01-2014_09_noHeaders.txt",names=my_cols, engine='python')
# Out:
# /Users/user/anaconda3/envs/dsi/lib/python3.6/site-packages/pandas/io/parsers.py:709: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)

# %%
isc = pd.DataFrame(isc)

# %%
isc.head()
# Out:
#     EVENTID     AUTHOR        DATE         TIME      LAT       LON  DEPTH  \
# 0    914299  GUTE       1904-01-20  14:52:06      7.0000  -79.0000   35.0
# 1  16957813  ISC        1904-04-04  10:25:34.15  42.4351   23.4138   15.0
# 2    914301  GUTE       1904-06-07  08:17:54     40.0000  134.0000  350.0
# 3  16957820  ISC        1904-06-25  14:45:39.96  51.5646  161.4174   15.0
# 4  16957819  ISC        1904-06-25  21:00:37.58  52.8642  160.4449   30.0
#
#    DEPFIX   AUTHOR.1    TYPE  MAG    AUTHOR2   TYPE2  MAG2    AUTHOR3   TYPE3  \
# 0  TRUE    PAS        MS      7.8  ABE1       mB       7.6  AN2        Ms
# 1  TRUE    PAS        MS      7.5  P&S        Ms       7.0  AN2        Ms
# 2          PAS        MS      7.5  ABE1       mB       7.4  UTSU       Mj
# 3  TRUE    PAS        MS      8.0  ABE1       mB       7.8  AN2        Ms
# 4  TRUE    PAS        MS      8.1  ABE1       mB       7.7  AN2        Ms
#
#    MAG3    AUTHOR4   TYPE4  MAG4    AUTHOR5   TYPE5  MAG5    AUTHOR6   TYPE6  \
# 0   7.2  P&S        Mw       7.2  GUTE       UK       7.8  PAS        UK
# 1   7.1  P&S        Mw       7.1  GUTE       UK       7.5       None    None
# 2   7.2  GUTE       UK       7.5  B&D        UK       7.9  PAS        UK
# 3   7.2  P&S        Mw       7.5  GUTE       UK       8.0  PAS        UK
# 4   7.4  P&S        Mw       7.6  GUTE       UK       8.1  PAS        UK
#
#    MAG6 AUTHOR7 TYPE7  MAG7 AUTHOR8 TYPE8  MAG8 AUTHOR9 TYPE9  MAG9 AUTHOR10  \
# 0   7.9    None  None   NaN    None  None   NaN    None  None   NaN     None
# 1   NaN    None  None   NaN    None  None   NaN    None  None   NaN     None
# 2   7.9    None  None   NaN    None  None   NaN    None  None   NaN     None
# 3   8.3    None  None   NaN    None  None   NaN    None  None   NaN     None
# 4   8.1    None  None   NaN    None  None   NaN    None  None   NaN     None
#
#   TYPE10  MAG10 AUTHOR11 TYPE11  MAG11 AUTHOR12 TYPE12  MAG12 AUTHOR13 TYPE13  \
# 0   None    NaN     None   None    NaN     None   None    NaN     None   None
# 1   None    NaN     None   None    NaN     None   None    NaN     None   None
# 2   None    NaN     None   None    NaN     None   None    NaN     None   None
# 3   None    NaN     None   None    NaN     None   None    NaN     None   None
# 4   None    NaN     None   None    NaN     None   None    NaN     None   None
#
#    MAG13 AUTHOR14 TYPE14  MAG14 AUTHOR15 TYPE15  MAG15 AUTHOR16 TYPE16  MAG16  \
# 0    NaN     None   None    NaN     None   None    NaN     None   None    NaN
# 1    NaN     None   None    NaN     None   None    NaN     None   None    NaN
# 2    NaN     None   None    NaN     None   None    NaN     None   None    NaN
# 3    NaN     None   None    NaN     None   None    NaN     None   None    NaN
# 4    NaN     None   None    NaN     None   None    NaN     None   None    NaN
#
#   AUTHOR17 TYPE17  MAG17 AUTHOR18 TYPE18  MAG18 AUTHOR19 TYPE19  MAG19  \
# 0     None   None    NaN     None   None    NaN     None   None    NaN
# 1     None   None    NaN     None   None    NaN     None   None    NaN
# 2     None   None    NaN     None   None    NaN     None   None    NaN
# 3     None   None    NaN     None   None    NaN     None   None    NaN
# 4     None   None    NaN     None   None    NaN     None   None    NaN
#
#   AUTHOR20 TYPE20  MAG20 AUTHOR21 TYPE21  MAG21 AUTHOR22 TYPE22  MAG22  \
# 0     None   None    NaN     None   None    NaN     None   None    NaN
# 1     None   None    NaN     None   None    NaN     None   None    NaN
# 2     None   None    NaN     None   None    NaN     None   None    NaN
# 3     None   None    NaN     None   None    NaN     None   None    NaN
# 4     None   None    NaN     None   None    NaN     None   None    NaN
#
#   AUTHOR23 TYPE23  MAG23 AUTHOR24 TYPE24  MAG24 AUTHOR25 TYPE25  MAG25  \
# 0     None   None    NaN     None   None    NaN     None   None    NaN
# 1     None   None    NaN     None   None    NaN     None   None    NaN
# 2     None   None    NaN     None   None    NaN     None   None    NaN
# 3     None   None    NaN     None   None    NaN     None   None    NaN
# 4     None   None    NaN     None   None    NaN     None   None    NaN
#
#   AUTHOR26 TYPE26  MAG26 AUTHOR27 TYPE27  MAG27 AUTHOR28 TYPE28  MAG28  \
# 0     None   None    NaN     None   None    NaN     None   None    NaN
# 1     None   None    NaN     None   None    NaN     None   None    NaN
# 2     None   None    NaN     None   None    NaN     None   None    NaN
# 3     None   None    NaN     None   None    NaN     None   None    NaN
# 4     None   None    NaN     None   None    NaN     None   None    NaN
#
#   AUTHOR29 TYPE29  MAG29 AUTHOR30 TYPE30  MAG30 AUTHOR31 TYPE31  MAG31  \
# 0     None   None    NaN     None   None    NaN     None   None    NaN
# 1     None   None    NaN     None   None    NaN     None   None    NaN
# 2     None   None    NaN     None   None    NaN     None   None    NaN
# 3     None   None    NaN     None   None    NaN     None   None    NaN
# 4     None   None    NaN     None   None    NaN     None   None    NaN
#
#   AUTHOR32 TYPE32  MAG32 AUTHOR33 TYPE33  MAG33 AUTHOR34 TYPE34  MAG34  \
# 0     None   None    NaN     None   None    NaN     None   None    NaN
# 1     None   None    NaN     None   None    NaN     None   None    NaN
# 2     None   None    NaN     None   None    NaN     None   None    NaN
# 3     None   None    NaN     None   None    NaN     None   None    NaN
# 4     None   None    NaN     None   None    NaN     None   None    NaN
#
#   AUTHOR35 TYPE35  MAG35 AUTHOR36 TYPE36  MAG36 AUTHOR37 TYPE37  MAG37  \
# 0     None   None    NaN     None   None    NaN     None   None    NaN
# 1     None   None    NaN     None   None    NaN     None   None    NaN
# 2     None   None    NaN     None   None    NaN     None   None    NaN
# 3     None   None    NaN     None   None    NaN     None   None    NaN
# 4     None   None    NaN     None   None    NaN     None   None    NaN
#
#   AUTHOR38 TYPE38  MAG38 AUTHOR39 TYPE39  MAG39 AUTHOR40 TYPE40  MAG40  \
# 0     None   None    NaN     None   None    NaN     None   None    NaN
# 1     None   None    NaN     None   None    NaN     None   None    NaN
# 2     None   None    NaN     None   None    NaN     None   None    NaN
# 3     None   None    NaN     None   None    NaN     None   None    NaN
# 4     None   None    NaN     None   None    NaN     None   None    NaN
#
#   AUTHOR41 TYPE41  MAG41 AUTHOR42 TYPE42  MAG42 AUTHOR43 TYPE43  MAG43  \
# 0     None   None    NaN     None   None    NaN     None   None    NaN
# 1     None   None    NaN     None   None    NaN     None   None    NaN
# 2     None   None    NaN     None   None    NaN     None   None    NaN
# 3     None   None    NaN     None   None    NaN     None   None    NaN
# 4     None   None    NaN     None   None    NaN     None   None    NaN
#
#   AUTHOR44 TYPE44  MAG44 AUTHOR45 TYPE45  MAG45 AUTHOR46 TYPE46  MAG46  \
# 0     None   None    NaN     None   None    NaN     None   None    NaN
# 1     None   None    NaN     None   None    NaN     None   None    NaN
# 2     None   None    NaN     None   None    NaN     None   None    NaN
# 3     None   None    NaN     None   None    NaN     None   None    NaN
# 4     None   None    NaN     None   None    NaN     None   None    NaN
#
#   AUTHOR47 TYPE47  MAG47 AUTHOR48 TYPE48  MAG48 AUTHOR49 TYPE49  MAG49  \
# 0     None   None    NaN     None   None    NaN     None   None    NaN
# 1     None   None    NaN     None   None    NaN     None   None    NaN
# 2     None   None    NaN     None   None    NaN     None   None    NaN
# 3     None   None    NaN     None   None    NaN     None   None    NaN
# 4     None   None    NaN     None   None    NaN     None   None    NaN
#
#   AUTHOR50 TYPE50  MAG50 AUTHOR51 TYPE51  MAG51 AUTHOR52 TYPE52  MAG52  \
# 0     None   None    NaN     None   None    NaN     None   None    NaN
# 1     None   None    NaN     None   None    NaN     None   None    NaN
# 2     None   None    NaN     None   None    NaN     None   None    NaN
# 3     None   None    NaN     None   None    NaN     None   None    NaN
# 4     None   None    NaN     None   None    NaN     None   None    NaN
#
#   AUTHOR53 TYPE53  MAG53 AUTHOR54 TYPE54  MAG54 AUTHOR55 TYPE55  MAG55  \
# 0     None   None    NaN     None   None    NaN     None   None    NaN
# 1     None   None    NaN     None   None    NaN     None   None    NaN
# 2     None   None    NaN     None   None    NaN     None   None    NaN
# 3     None   None    NaN     None   None    NaN     None   None    NaN
# 4     None   None    NaN     None   None    NaN     None   None    NaN
#
#   AUTHOR56 TYPE56  MAG56 AUTHOR57 TYPE57  MAG57 AUTHOR58 TYPE58  MAG58  \
# 0     None   None    NaN     None   None    NaN     None   None    NaN
# 1     None   None    NaN     None   None    NaN     None   None    NaN
# 2     None   None    NaN     None   None    NaN     None   None    NaN
# 3     None   None    NaN     None   None    NaN     None   None    NaN
# 4     None   None    NaN     None   None    NaN     None   None    NaN
#
#   AUTHOR59 TYPE59  MAG59  AUTHOR60  TYPE60  MAG60  AUTHOR61  TYPE61  MAG61  \
# 0     None   None    NaN       NaN     NaN    NaN       NaN     NaN    NaN
# 1     None   None    NaN       NaN     NaN    NaN       NaN     NaN    NaN
# 2     None   None    NaN       NaN     NaN    NaN       NaN     NaN    NaN
# 3     None   None    NaN       NaN     NaN    NaN       NaN     NaN    NaN
# 4     None   None    NaN       NaN     NaN    NaN       NaN     NaN    NaN
#
#    AUTHOR62  TYPE62  MAG62  AUTHOR63  TYPE63  MAG63  AUTHOR64  TYPE64  MAG64  \
# 0       NaN     NaN    NaN       NaN     NaN    NaN       NaN     NaN    NaN
# 1       NaN     NaN    NaN       NaN     NaN    NaN       NaN     NaN    NaN
# 2       NaN     NaN    NaN       NaN     NaN    NaN       NaN     NaN    NaN
# 3       NaN     NaN    NaN       NaN     NaN    NaN       NaN     NaN    NaN
# 4       NaN     NaN    NaN       NaN     NaN    NaN       NaN     NaN    NaN
#
#    AUTHOR65  TYPE65  MAG65  AUTHOR66  TYPE66  MAG66  AUTHOR67  TYPE67  MAG67  \
# 0       NaN     NaN    NaN       NaN     NaN    NaN       NaN     NaN    NaN
# 1       NaN     NaN    NaN       NaN     NaN    NaN       NaN     NaN    NaN
# 2       NaN     NaN    NaN       NaN     NaN    NaN       NaN     NaN    NaN
# 3       NaN     NaN    NaN       NaN     NaN    NaN       NaN     NaN    NaN
# 4       NaN     NaN    NaN       NaN     NaN    NaN       NaN     NaN    NaN
#
#    AUTHOR68  TYPE68  MAG68
# 0       NaN     NaN    NaN
# 1       NaN     NaN    NaN
# 2       NaN     NaN    NaN
# 3       NaN     NaN    NaN
# 4       NaN     NaN    NaN

# %%
isc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1835927 entries, 0 to 1835926
# Columns: 212 entries, EVENTID to MAG68
# dtypes: float64(88), int64(1), object(123)
# memory usage: 2.9+ GB

# %%
isc.shape
# Out:
# (1835927, 212)

# %%
#mag_isc = list(isc['MAG'])
isc['MAG'].unique()
# Out:
# array([ 7.8,  7.5,  8. ,  8.1,  7.9,  7. ,  8.2,  7.2,  6.8,  nan,  8.4,
#         6.5,  7.6,  7.4,  6.6,  6.9,  6.7,  7.3,  6.3,  7.1,  6.1,  6.4,
#         5.8,  6.2,  7.7,  6. ,  5.6,  5.9,  5.5,  8.6,  8.3,  8.7,  5. ,
#         5.2,  5.7,  5.4,  5.3,  3.5,  3.6,  5.1,  3.8,  3. ,  4. ,  4.4,
#         3.4,  3.2,  4.2,  3.7,  4.6,  2.9,  4.3,  3.3,  3.1,  4.5,  3.9,
#         4.1,  4.8,  2.8,  2.7,  2.6,  4.7,  2.3,  2.5,  4.9,  1. ,  2. ,
#         2.4,  1.5,  1.3,  1.2,  1.1,  2.2,  2.1,  1.9,  1.8,  1.4,  1.6,
#         1.7,  0.5,  0.3,  0.8,  0. ,  0.6,  0.7,  0.9,  0.2,  0.4,  0.1,
#        -0.2, -0.7, -0.3, -0.1, -0.4, -0.5, -0.6, -0.9])

# %%
isc['MAG'].isnull().sum()
# Out:
# 240820

# %%
isc_mag = isc[isc['MAG'].notnull()]

# %%
isc_mag.shape
# Out:
# (1595107, 212)

# %%
type(isc['MAG'])
# Out:
# pandas.core.series.Series

# %%
# Histogram 

plt.hist(isc_mag['MAG'])    
# Add title and axis names
plt.title('ISC Earthquake Catalog Histogram')
plt.xlabel('Earthquake Magnitude') #Default is 10 bins
plt.ylabel('Count')
#plt.xlim(0,10)

# Show graphic
plt.show()

# %%
sns.set(rc={'figure.figsize':(12,9)})
f,ax = plt.subplots()
sns.distplot(isc_mag['MAG'], bins=50, axlabel ='Earthquake Magnitude')
ax.set_title('ISC Earthquake Catalog Histogram')
ax.set_xlabel('Earthquake Magnitude');
ax.set_ylabel('Count');

# %%
pd.crosstab(index=isc_mag['MAG'],  # Make a crosstab
                      columns="count")      # Name the count column
# Out:
# col_0  count
# MAG
# -0.9       1
# -0.7       2
# -0.6       1
# -0.5       2
# -0.4       1
# -0.3      11
# -0.2       6
# -0.1      11
#  0.0     466
#  0.1     112
#  0.2     175
#  0.3     166
#  0.4     228
#  0.5     320
#  0.6     387
#  0.7     488
#  0.8     650
#  0.9     854
#  1.0    1921
#  1.1    1609
#  1.2    2112
#  1.3    2901
#  1.4    3922
#  1.5    5255
#  1.6    6826
#  1.7    8665
#  1.8   10647
#  1.9   12670
#  2.0   17351
#  2.1   18844
# ...      ...
#  5.7    2608
#  5.8    2442
#  5.9    1553
#  6.0    1999
#  6.1     918
#  6.2    1234
#  6.3     672
#  6.4     518
#  6.5     857
#  6.6     338
#  6.7     231
#  6.8     422
#  6.9     192
#  7.0     295
#  7.1     135
#  7.2     168
#  7.3      90
#  7.4      55
#  7.5      77
#  7.6      47
#  7.7      25
#  7.8      60
#  7.9      21
#  8.0      14
#  8.1      11
#  8.2      16
#  8.3       6
#  8.4       2
#  8.6       3
#  8.7       2
#
# [95 rows x 1 columns]

# %%
# Scatter plot of Earthquakes vs. Time for The USGS
 
# Without regression fit:
f,ax = plt.subplots()
sns.regplot(x=isc_mag['Date_temp'], y=isc_mag['MAG'], fit_reg=False, ax = ax)
ax.set_title('The ISC Catalog Scatter plot Time vs Earthquake Magnitude')
ax.set_xlabel('Time (Years)');
ax.set_ylabel('Earthquake Magnitude');

# %%
# Loading the ISSN_M_tot data
ISSN_M_tot = pd.read_csv('./ISSN_M_tot.csv')

# %%
ISSN_M_tot = pd.DataFrame(ISSN_M_tot)

# %%
len(ISSN_M_tot)
# Out:
# 3193

# %%
ISSN_M_tot.head()
# Out:
#    1749  01  1749.049   58.0  1   -1.0  1.1
# 0  1749   2  1749.129   62.6  1   -1.0    1
# 1  1749   3  1749.210   70.0  1   -1.0    1
# 2  1749   4  1749.294   55.7  1   -1.0    1
# 3  1749   5  1749.377   85.0  1   -1.0    1
# 4  1749   6  1749.461   83.5  1   -1.0    1

# %%
# Loading the ISSN_D_tot data
ISSN_D_tot = pd.read_csv('./ISSN_D_tot.csv')

# %%
ISSN_D_tot = pd.DataFrame(ISSN_D_tot)

# %%
len(ISSN_D_tot)
# Out:
# 72011

# %%
ISSN_D_tot.head()
# Out:
#    1818  01  01.1  1818.004   -1  1
# 0  1818   1     2  1818.007   -1  1
# 1  1818   1     3  1818.010   -1  1
# 2  1818   1     4  1818.012   -1  1
# 3  1818   1     5  1818.015   -1  1
# 4  1818   1     6  1818.018   -1  1

# %%
# Loading the ISSN_Y_tot data
ISSN_Y_tot = pd.read_csv('./ISSN_Y_tot.csv')

# %%
ISSN_Y_tot = pd.DataFrame(ISSN_Y_tot)

# %%
len(ISSN_Y_tot)
# Out:
# 314

# %%
ISSN_Y_tot.head()
# Out:
#    1700.5    5.0  1
# 0  1701.5   11.0  1
# 1  1702.5   16.0  1
# 2  1703.5   23.0  1
# 3  1704.5   36.0  1
# 4  1705.5   58.0  1
